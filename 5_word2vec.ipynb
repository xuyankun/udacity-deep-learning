# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3081, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'of', 'term', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.386826
# Nearest to states: screenwriter, analogs, speculate, ella, angie, heated, stockpiles, slocum,
# Nearest to on: brythonic, neglected, hallmark, canonized, electrified, trolling, traces, deciphering,
# Nearest to seven: catholic, sentences, covariance, rashi, appearances, salads, madhuri, sunga,
# Nearest to have: eamon, westmoreland, eighteenth, shaykh, alumnus, montmartre, bittering, width,
# Nearest to he: geller, observes, except, prosperous, noble, hunan, ashikaga, suppress,
# Nearest to such: marston, replicant, augusti, riddled, edition, subsidence, cantonese, rouse,
# Nearest to during: buoyed, possessor, debauchery, cheapest, triumphs, js, quicksilver, counterclockwise,
# Nearest to their: guidelines, deposition, trainer, announcing, chaining, servants, gaston, endlessly,
# Nearest to i: molybdenum, devolution, nonterminal, holding, priesthood, schema, whiteness, zealots,
# Nearest to use: cheated, creating, bootp, tunes, bassoonist, hetzel, gygax, lantau,
# Nearest to new: scurvy, perceptual, repetitions, whitaker, prison, jeho, pokey, hailed,
# Nearest to for: base, feedback, orang, proliferated, maneuvers, essex, pheromones, francis,
# Nearest to however: carducci, damaged, experiments, hksar, charcoal, filmography, police, vlad,
# Nearest to after: seem, geraldine, gb, beavis, unleavened, pegbox, comanche, noteworthy,
# Nearest to people: tsunamis, milliardo, jealousy, computational, swordsman, patenting, earning, taxonomists,
# Nearest to first: gruyter, involving, augustinians, ward, spindle, lutz, glover, empires,
# Average loss at step 2000: 4.366890
# Average loss at step 4000: 3.867730
# Average loss at step 6000: 3.786457
# Average loss at step 8000: 3.688374
# Average loss at step 10000: 3.618278
# Nearest to states: symplectic, screenwriter, analogs, slocum, converging, spaniel, bari, smoothness,
# Nearest to on: in, from, by, with, upon, at, of, felix,
# Nearest to seven: six, eight, five, three, nine, four, zero, two,
# Nearest to have: be, had, has, were, are, rotting, cuthbert, reemergence,
# Nearest to he: it, they, she, who, wreckage, there, but, targaryen,
# Nearest to such: rouse, known, wordperfect, edition, monaro, gif, replicant, these,
# Nearest to during: mm, within, mundi, into, buoyed, warwickshire, trombone, pulitzer,
# Nearest to their: his, its, the, trainer, welch, condita, this, punished,
# Nearest to i: nonterminal, devolution, macmanus, sinai, circassians, holds, ashcroft, molybdenum,
# Nearest to use: dorset, klister, name, bassoonist, yn, anthropology, creating, cumings,
# Nearest to new: repetitions, baking, perceptual, dflp, jeho, scurvy, gymnasium, shaved,
# Nearest to for: with, of, from, in, unimportant, like, original, regolith,
# Nearest to however: filmography, carducci, hksar, quickdraw, architectures, komodo, christe, pessoa,
# Nearest to after: unleavened, gb, with, comanche, following, before, edgar, leche,
# Nearest to people: unlucky, portal, melodies, decatur, immigrants, presently, computational, jealousy,
# Nearest to first: helped, augustinians, gruyter, automator, tantra, biosynthesis, concomitant, solving,
# Average loss at step 12000: 3.601685
# Average loss at step 14000: 3.575020
# Average loss at step 16000: 3.409619
# Average loss at step 18000: 3.456495
# Average loss at step 20000: 3.538537
# Nearest to states: symplectic, analogs, converging, smoothness, lacrosse, kingdom, screenwriter, bevin,
# Nearest to on: in, upon, neglected, during, through, at, into, bananas,
# Nearest to seven: eight, six, nine, three, four, five, two, zero,
# Nearest to have: had, has, be, were, are, brewer, chances, sle,
# Nearest to he: it, she, they, who, there, but, wreckage, never,
# Nearest to such: known, these, well, wordperfect, chakra, vc, aug, gatt,
# Nearest to during: until, in, into, on, within, following, mm, but,
# Nearest to their: his, its, the, her, these, yar, trainer, assumes,
# Nearest to i: ii, ashcroft, circassians, nonterminal, macmanus, limassol, amyl, exhaustion,
# Nearest to use: dorset, klister, name, seater, bassoonist, yn, cars, adapters,
# Nearest to new: jeho, repetitions, baking, revolt, perceptual, sophisticated, eurythmics, saucer,
# Nearest to for: of, from, in, original, testes, feedback, by, with,
# Nearest to however: but, that, quickdraw, affiliations, police, komodo, christe, transforms,
# Nearest to after: before, unleavened, edgar, gb, pedagogical, throughout, following, with,
# Nearest to people: portal, melodies, abbreviations, decatur, unlucky, ripened, immigrants, jealousy,
# Nearest to first: last, latter, gruyter, same, concomitant, legacies, next, second,
# Average loss at step 22000: 3.506189
# Average loss at step 24000: 3.489408
# Average loss at step 26000: 3.478395
# Average loss at step 28000: 3.484669
# Average loss at step 30000: 3.504694
# Nearest to states: kingdom, symplectic, tolkien, mdi, smoothness, cases, converging, analogs,
# Nearest to on: upon, in, during, through, from, bananas, amassing, around,
# Nearest to seven: eight, nine, four, six, five, three, zero, two,
# Nearest to have: had, has, were, be, are, having, include, chandrasekhar,
# Nearest to he: it, she, they, who, there, wreckage, but, never,
# Nearest to such: well, these, known, vc, wordperfect, antidepressants, halved, karakoram,
# Nearest to during: after, until, in, into, on, when, but, from,
# Nearest to their: his, its, the, her, these, our, some, shadowed,
# Nearest to i: ii, circassians, we, g, horst, iii, ashcroft, acclamation,
# Nearest to use: klister, bassoonist, dorset, internetwork, gettysburg, adapters, dialects, vendors,
# Nearest to new: largest, repetitions, baking, tramlink, jeho, second, rightness, blanche,
# Nearest to for: against, unimportant, original, honed, when, feedback, during, xerox,
# Nearest to however: but, although, that, quickdraw, while, though, and, there,
# Nearest to after: before, during, unleavened, when, edgar, throughout, following, pedagogical,
# Nearest to people: portal, melodies, children, jews, those, beeswax, supporters, profiles,
# Nearest to first: second, last, next, same, third, augustinians, hegelians, usk,
# Average loss at step 32000: 3.496958
# Average loss at step 34000: 3.494153
# Average loss at step 36000: 3.455958
# Average loss at step 38000: 3.305245
# Average loss at step 40000: 3.428026
# Nearest to states: kingdom, symplectic, smoothness, tolkien, mdi, cases, nations, tatars,
# Nearest to on: upon, at, amassing, during, chalcedon, in, bananas, klein,
# Nearest to seven: eight, six, nine, five, four, three, two, zero,
# Nearest to have: had, has, were, be, are, having, already, happen,
# Nearest to he: she, it, they, there, who, i, wreckage, eventually,
# Nearest to such: well, these, known, monaro, cantonese, including, antidepressants, wordperfect,
# Nearest to during: after, until, on, andrea, in, when, within, following,
# Nearest to their: its, his, her, the, these, some, our, both,
# Nearest to i: we, ii, acclamation, you, they, he, t, circassians,
# Nearest to use: klister, bassoonist, adapters, internetwork, veracity, dorset, modem, musicologist,
# Nearest to new: baking, duodenum, jeho, rightness, talkin, remembrance, perceptual, whitaker,
# Nearest to for: unimportant, in, honed, against, from, when, of, by,
# Nearest to however: but, although, that, though, while, lyndon, did, quickdraw,
# Nearest to after: before, during, when, unleavened, pedagogical, edgar, while, doodle,
# Nearest to people: those, immigrants, melodies, lysine, children, abbreviations, profiles, jews,
# Nearest to first: second, last, next, third, maneuverable, same, fielding, hegelians,
# Average loss at step 42000: 3.431421
# Average loss at step 44000: 3.449501
# Average loss at step 46000: 3.451865
# Average loss at step 48000: 3.355812
# Average loss at step 50000: 3.378410
# Nearest to states: kingdom, smoothness, symplectic, christa, tolkien, cases, nations, mdi,
# Nearest to on: upon, amassing, in, at, neglected, over, popper, through,
# Nearest to seven: six, eight, four, nine, three, five, zero, two,
# Nearest to have: had, has, were, be, are, having, who, happen,
# Nearest to he: she, it, they, who, there, eventually, wreckage, creationists,
# Nearest to such: these, well, known, including, many, antidepressants, monaro, efficient,
# Nearest to during: after, when, until, in, following, but, while, andrea,
# Nearest to their: its, his, the, her, these, our, whose, both,
# Nearest to i: we, ii, you, acclamation, t, methuen, g, they,
# Nearest to use: musicologist, klister, dorset, ecd, end, supposition, mind, veracity,
# Nearest to new: duodenum, talkin, largest, baking, second, tramlink, whitaker, pvp,
# Nearest to for: against, while, despite, cucumbers, crichton, phantom, thynne, honed,
# Nearest to however: but, although, that, though, while, when, shahanshah, during,
# Nearest to after: before, during, when, while, unleavened, pedagogical, following, though,
# Nearest to people: children, immigrants, supporters, jews, profiles, portal, melodies, men,
# Nearest to first: second, last, next, third, latter, fielding, hardin, oldest,
# Average loss at step 52000: 3.439041
# Average loss at step 54000: 3.430897
# Average loss at step 56000: 3.438337
# Average loss at step 58000: 3.396660
# Average loss at step 60000: 3.396623
# Nearest to states: kingdom, nations, symplectic, countries, smoothness, cases, mdi, rodman,
# Nearest to on: upon, through, neglected, amassing, in, bananas, duplications, incense,
# Nearest to seven: eight, four, six, nine, five, three, zero, one,
# Nearest to have: has, had, were, are, having, include, require, chandrasekhar,
# Nearest to he: she, it, they, there, eventually, who, then, we,
# Nearest to such: these, well, known, many, including, certain, alberts, antidepressants,
# Nearest to during: after, following, until, in, although, since, before, when,
# Nearest to their: its, his, her, our, the, whose, these, some,
# Nearest to i: ii, we, you, acclamation, they, methuen, t, g,
# Nearest to use: ecd, significance, most, infrastructures, role, nanomachines, internetwork, think,
# Nearest to new: baking, largest, repetitions, hindemith, particular, talkin, massed, tupac,
# Nearest to for: including, of, without, unimportant, thynne, despite, to, stringent,
# Nearest to however: but, although, that, though, while, during, edsel, when,
# Nearest to after: before, during, when, while, unleavened, following, since, shyness,
# Nearest to people: children, immigrants, men, those, melodies, women, lysine, supporters,
# Nearest to first: last, second, next, latter, third, same, only, fourth,
# Average loss at step 62000: 3.241909
# Average loss at step 64000: 3.253118
# Average loss at step 66000: 3.403119
# Average loss at step 68000: 3.396318
# Average loss at step 70000: 3.361660
# Nearest to states: kingdom, nations, state, symplectic, countries, smoothness, tolkien, christa,
# Nearest to on: upon, in, through, around, duplications, amassing, between, bananas,
# Nearest to seven: six, eight, four, nine, five, three, two, zero,
# Nearest to have: had, has, were, are, having, require, include, be,
# Nearest to he: she, it, they, there, eventually, who, we, flared,
# Nearest to such: these, well, known, including, many, antidepressants, molecular, other,
# Nearest to during: after, until, in, before, however, although, within, following,
# Nearest to their: its, his, her, the, our, these, whose, some,
# Nearest to i: ii, we, you, g, methuen, acclamation, grammarian, they,
# Nearest to use: ecd, most, significance, turn, think, musicologist, allow, translocation,
# Nearest to new: pvp, baking, hindemith, repetitions, latest, talkin, tupac, remembrance,
# Nearest to for: honed, including, through, in, unimportant, if, like, against,
# Nearest to however: but, although, while, that, though, where, when, during,
# Nearest to after: before, during, when, while, following, unleavened, pedagogical, if,
# Nearest to people: children, men, women, immigrants, melodies, members, individuals, supporters,
# Nearest to first: second, last, next, third, fourth, same, current, fielding,
# Average loss at step 72000: 3.379236
# Average loss at step 74000: 3.347665
# Average loss at step 76000: 3.315385
# Average loss at step 78000: 3.354432
# Average loss at step 80000: 3.375247
# Nearest to states: kingdom, nations, state, symplectic, smoothness, countries, israel, rodman,
# Nearest to on: upon, through, in, at, popper, sinless, neglected, amassing,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to have: had, has, are, having, be, were, require, include,
# Nearest to he: she, it, they, there, who, eventually, never, we,
# Nearest to such: well, these, known, including, certain, antidepressants, buddhists, regarded,
# Nearest to during: after, in, until, when, before, throughout, although, at,
# Nearest to their: its, his, her, our, the, your, these, some,
# Nearest to i: ii, you, g, we, acclamation, methuen, t, clark,
# Nearest to use: musicologist, think, significance, klister, appropriation, ecd, entanglement, ability,
# Nearest to new: baking, pvp, talkin, patass, hindemith, latest, reiter, putting,
# Nearest to for: despite, unimportant, if, honed, kusakabe, excretion, propane, stringent,
# Nearest to however: although, but, that, while, though, where, during, when,
# Nearest to after: before, when, during, while, following, despite, if, without,
# Nearest to people: men, children, women, jews, individuals, members, immigrants, melodies,
# Nearest to first: second, last, next, third, fourth, same, final, current,
# Average loss at step 82000: 3.406171
# Average loss at step 84000: 3.406198
# Average loss at step 86000: 3.390740
# Average loss at step 88000: 3.355654
# Average loss at step 90000: 3.364199
# Nearest to states: kingdom, state, nations, us, symplectic, misconception, abridgment, mdi,
# Nearest to on: upon, under, neglected, in, at, anesthetics, through, bananas,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to have: had, has, were, require, are, having, be, tend,
# Nearest to he: she, it, they, there, who, eventually, never, originally,
# Nearest to such: well, these, known, including, many, certain, antidepressants, regarded,
# Nearest to during: after, in, until, before, throughout, at, while, despite,
# Nearest to their: its, his, her, your, our, the, whose, my,
# Nearest to i: ii, g, we, you, acclamation, iii, infty, divx,
# Nearest to use: application, significance, practice, ecd, entanglement, allow, most, visualization,
# Nearest to new: particular, talkin, hindemith, baking, remembrance, commonsense, competing, counterattacks,
# Nearest to for: despite, including, while, of, against, honed, cucumbers, without,
# Nearest to however: but, although, that, though, while, motala, where, cases,
# Nearest to after: before, during, when, while, until, if, despite, without,
# Nearest to people: women, children, men, jews, players, members, immigrants, melodies,
# Nearest to first: last, second, next, third, fourth, latter, same, current,
# Average loss at step 92000: 3.399114
# Average loss at step 94000: 3.260330
# Average loss at step 96000: 3.358217
# Average loss at step 98000: 3.244622
# Average loss at step 100000: 3.358547
# Nearest to states: kingdom, nations, state, smoothness, us, christa, abridgment, venerated,
# Nearest to on: upon, in, at, under, amassing, through, around, near,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to have: had, has, were, require, are, be, include, having,
# Nearest to he: she, it, they, there, we, who, never, eventually,
# Nearest to such: well, known, these, many, including, antidepressants, certain, notable,
# Nearest to during: in, after, throughout, despite, until, at, within, when,
# Nearest to their: his, its, her, your, our, the, whose, these,
# Nearest to i: ii, we, you, g, t, acclamation, they, iii,
# Nearest to use: application, significance, appropriation, practice, entanglement, sense, most, allow,
# Nearest to new: baking, remembrance, talkin, pvp, particular, latest, kriegsmarine, counterattacks,
# Nearest to for: when, despite, including, against, thynne, if, after, cucumbers,
# Nearest to however: but, although, that, while, though, especially, where, and,
# Nearest to after: before, when, during, while, without, if, despite, following,
# Nearest to people: children, women, jews, men, immigrants, players, individuals, members,
# Nearest to first: last, second, next, third, fourth, fifth, best, final,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
